# %%
import cv2
import matplotlib.pyplot as plt
import torch

img_path = "../Data/JPEGImages/2007_000032.jpg"
mask_path = "../Data/SegmentationClass/2007_000032.png"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

img = torch.tensor(img)
mask = torch.tensor(mask)

print("Image:", img.shape)
print("Mask:", mask.shape)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.imshow(img)
plt.title("Image")

plt.subplot(1,2,2)
plt.imshow(mask)
plt.title("Mask")

plt.show()
# Out:
# Image: torch.Size([281, 500, 3])
# Mask: torch.Size([281, 500])
